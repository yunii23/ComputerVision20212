# %% [markdown]
# ### 1.4.4 Smoothing Images

# %%
import cv2
import numpy as np

# %%
from matplotlib import pyplot as plt

# %%
img = cv2.imread('opencv2.png')
n=17
kernel = np.ones((n,n),np.float32)/25
dst = cv2.filter2D(img,-1,kernel)
plt.rcParams["figure.figsize"] = (20,10)
plt.subplot(121),plt.imshow(img),plt.title('Original')
plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(dst),plt.title('Averaging')
plt.xticks([]), plt.yticks([])
plt.show()

# %%
np.ones((5,5),np.float32)/25
# Out:
# array([[0.04, 0.04, 0.04, 0.04, 0.04],
#        [0.04, 0.04, 0.04, 0.04, 0.04],
#        [0.04, 0.04, 0.04, 0.04, 0.04],
#        [0.04, 0.04, 0.04, 0.04, 0.04],
#        [0.04, 0.04, 0.04, 0.04, 0.04]], dtype=float32)

# %%
sum(sum(kernel))
# Out:
# 0.9999999403953552

# %%
#img = cv2.imread('opencv2.png')
img = cv2.imread('texture.jpg')

#n=17
#kernel = np.ones((n,n),np.float32)/25
#dst = cv2.filter2D(img,-1,kernel)
# 위 함수 세 줄이 blur = cv2.blur(img,(5,5)) 얘랑 같은 것

#n = 10
#blur = cv2.blur(img,(n,n))

# n=11
#blur = cv2.GaussianBlur(img,(n,n),0)

#n=5
#blur = cv2.medianBlur(img,n)

#직선 성향의 스트라이프 텍스처에서 사용하면 효과 볼 수 있음
blur = cv2.bilateralFilter(img,9,75,75)


plt.rcParams["figure.figsize"] = (20,10)
plt.subplot(121),plt.imshow(img),plt.title('Original')
plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(blur),plt.title('Blurred')
plt.xticks([]), plt.yticks([])
plt.show()
