# %%
somechar = 5
for somechar in "Hello World":
    print somechar
# Out:
#   File "<ipython-input-1-2dbcc8d7e145>", line 3
#     print somechar
#           ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(somechar)?

# %%
for somechar in "Hello World":
    print (somechar)
# Out:
# H
# e
# l
# l
# o
#
# W
# o
# r
# l
# d

# %%
for (x,y) in [('a',1), ('b',2), ('c',3), ('d',4)]:
    print (x)
# Out:
# a
# b
# c
# d

# %%
for x in range(5) :
    print(x)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
mylist = ['one', 'two', 'three']
for i in range(len(mylist)):
    print(i, mylist[i])
# Out:
# 0 one
# 1 two
# 2 three

# %%
mylist = ['one', 'two', 'three'] 
for (i, item) in enumerate(mylist):
    print (i, item)
# Out:
# 0 one
# 1 two
# 2 three
