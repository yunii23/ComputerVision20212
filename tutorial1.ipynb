# %%
1+2
# Out:
# 3

# %%
x, y = 2, 3

# %%
x
# Out:
# 2

# %%
y
# Out:
# 3

# %%
tu = (23, 'abc', 4.56, (2,3), 'def')

# %%
tu
# Out:
# (23, 'abc', 4.56, (2, 3), 'def')

# %%
li = ["abc", 34, 4.34, 23]

# %%
li
# Out:
# ['abc', 34, 4.34, 23]

# %%
st = "Hello World"

# %%
st
# Out:
# 'Hello World'

# %%
st = 'Hello World'

# %%
st
# Out:
# 'Hello World'

# %%
st = """This is a multi-line string that uses triple quotes."""

# %%
st
# Out:
# 'This is a multi-line string that uses triple quotes.'

# %%
print(st)
# Out:
# This is a multi-line string that uses triple quotes.

# %%
print(li)
# Out:
# ['abc', 34, 4.34, 23]

# %%
li[-2]
# Out:
# 4.34

# %%
tu[0]
# Out:
# 23

# %%
tu[-1]
# Out:
# 'def'

# %%
tu[4]
# Out:
# 'def'

# %%
tu[1:4]
# Out:
# ('abc', 4.56, (2, 3))

# %%
tu[1:-1]
# Out:
# ('abc', 4.56, (2, 3))

# %%
tu[1:-1:2]
# Out:
# ('abc', (2, 3))

# %%
tu[-2]
# Out:
# (2, 3)

# %%
tu[-4]
# Out:
# 'abc'

# %%
tu[:2]
# Out:
# (23, 'abc')

# %%
tu[:4]
# Out:
# (23, 'abc', 4.56, (2, 3))

# %%
tu[2:5]
# Out:
# (4.56, (2, 3), 'def')

# %%
tu[2:]
# Out:
# (4.56, (2, 3), 'def')

# %%
tu[:]
# Out:
# (23, 'abc', 4.56, (2, 3), 'def')

# %%
tu1 = tu

# %%
tu1
# Out:
# (23, 'abc', 4.56, (2, 3), 'def')

# %%
tu1[0] = 1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-33-d2e38954a248> in <module>
# ----> 1 tu1[0] = 1
#
# TypeError: 'tuple' object does not support item assignment

# %%
li = [23, 'abc', 4.56, (2, 3), 'def']

# %%
print(li)
# Out:
# [23, 'abc', 4.56, (2, 3), 'def']

# %%
li[0] = 1

# %%
print(li)
# Out:
# [1, 'abc', 4.56, (2, 3), 'def']
