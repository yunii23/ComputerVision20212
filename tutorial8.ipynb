# %%
def myfun(x,y):
    return x*y

# %%
myfun(3,4)
# Out:
# 12

# %%
def myfun(x):
    return x*3

# %%
def apply(q,x):
    return q(x)

# %%
apply(myfun, 7)
# Out:
# 21

# %%
apply(lambda z:z*4, 7)
# Out:
# 28

# %%
def myfun(b, c=3, d="hello"):
    return b+c

# %%
myfun(5,3,"hello")
# Out:
# 8

# %%
myfun(5,3)
# Out:
# 8

# %%
myfun(5)
# Out:
# 8

# %%
def myfun(a,b,c):
    return a-b

# %%
myfun(2,1,43)
# Out:
# 1

# %%
myfun(c=43,b=1,a=2)
# Out:
# 1

# %%
myfun(2,c=43,b=1)
# Out:
# 1

# %% [markdown]
# -----

# %%
"hello".upper()
# Out:
# 'HELLO'

# %%
x='abc'

# %%
y=34

# %%
print('%s xyz %d' % (x,y))
# Out:
# abc xyz 34

# %%
print('%s xyz %d' % ('abc', 34))
# Out:
# abc xyz 34

# %%
print('abc')
# Out:
# abc

# %%
print('abc', 'def')
# Out:
# abc def

# %%
";".join(["abc", "def", "ghi"])
# Out:
# 'abc;def;ghi'

# %%
'abc;def;ghi'.split(";")
# Out:
# ['abc', 'def', 'ghi']

# %%
"Hello " + str(2)
# Out:
# 'Hello 2'

# %% [markdown]
# -------

# %%
class student:
    def __init__(self, name, Age):
        self.full_name = name
        self.age = Age
        
    def __repr__(self):
        return "I'm named " + self.full_name

# %%
f = student("Bob smith", 23)

# %%
print (f)
# Out:
# I'm named Bob smith

# %%
f
# Out:
# I'm named Bob smith

# %%
print(f.__doc__)
# Out:
# None

# %%
f.__class__
# Out:
# __main__.student

# %%
g = f.__class__("Tom Jones", 34)

# %% [markdown]
# ------

# %%
def divide(x,y):
    try:
        result = x/y
    except ZeroDivisionError:
        print ("division by zero!")
    else: 
        print ("result is", result)
    finally:
        print ("executing finally clause")

# %%
divide(2,1)
# Out:
# result is 2.0
# executing finally clause

# %%
divide(2,0)
# Out:
# division by zero!
# executing finally clause

# %%
divide("2","1")
# Out:
# executing finally clause
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-52-c4579e894624> in <module>
# ----> 1 divide("2","1")
#
# <ipython-input-49-330a8af52da4> in divide(x, y)
#       1 def divide(x,y):
#       2     try:
# ----> 3         result = x/y
#       4     except ZeroDivisionError:
#       5         print ("division by zero!")
#
# TypeError: unsupported operand type(s) for /: 'str' and 'str'

# %% [markdown]
# ----

# %% [markdown]
# for e in [1,2]:
#     print (e)

# %%
s = [1,2]

# %%
it = iter(s)

# %%
it

# %%
it.next()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-58-24d6ab57088b> in <module>
# ----> 1 it.next()
#
# AttributeError: 'list_iterator' object has no attribute 'next'

# %% [markdown]
# -----

# %% [markdown]
# ------

# %%
class Reverse:
    "Iterator for looping over a sequence backwards"
    def __init__(self, data):
        self.data = data
        self.index = len(data)
    def __next__(self):
        if self.index == 0:
            raise StopIteration
        self.index = self.index - 1
        return self.data[self.index]
    def __iter__(self):
        return self

# %%
for char in Reverse('spam'):
    print(char)
# Out:
# m
# a
# p
# s

# %%
[x for x in Reverse('spam')]
# Out:
# ['m', 'a', 'p', 's']

# %%
[x + x for x in Reverse('spam')]
# Out:
# ['mm', 'aa', 'pp', 'ss']

# %% [markdown]
# ------

# %%
def reverse(data):
    for i in range(len(data)):
        yield data[len(data)-1-i]

# %%
for char in reverse('spam'):
    print(char)
# Out:
# m
# a
# p
# s

# %%
def merge(l, r):
    llen, rlen, i, j = len(l), len(r), 0, 0
    while i < llen or j < rlen:
        if j == rlen or (i < llen and l[i] < r[j]):
            yield l[i]
            i += 1
        else:
            yield r[j]
            j += 1

# %%
g = merge([2,4], [1,3,5])

# %%
while True:
    print (g.next())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-72-551dc99799af> in <module>
#       1 while True:
# ----> 2     print (g.next())
#
# AttributeError: 'generator' object has no attribute 'next'

# %%
[x for x in merge([1,3,5], [2,4])]
# Out:
# [1, 2, 3, 4, 5]

# %%
g =  merge([2,4], [1, 3, 5])

# %%
while True:
    try:
        print (g.next())
    except StopIteration:
        print ('Done')
        break
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-75-ddf2c9568963> in <module>
#       1 while True:
#       2     try:
# ----> 3         print (g.next())
#       4     except StopIteration:
#       5         print ('Done')
#
# AttributeError: 'generator' object has no attribute 'next'

# %%
a = (x * x for x in xrange(5))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-76-10cd84004be0> in <module>
# ----> 1 a = (x * x for x in xrange(5))
#
# NameError: name 'xrange' is not defined

# %% [markdown]
# ------------

# %% [markdown]
# -----------

# %%
class DiGraph:
    def __init__(self, edges):
        self.adj = {}
        for u,v in edges:
            if u not in self.adj: self.adj[u] = [v]
            else: self.adj[u].append(v) 
    def __str__(self):
        return '\n'.join(['%s -> %s'%(u,v) \
                            for u in self.adj for v in self.adj[u]])

    def search(self, u, visited=set()):
        # If we haven't already visited this node...
        if u not in visited: 
            # yield it
            yield u
            # and remember we've visited it now.
            visited.add(u) 
            # Then, if there are any adjacant nodes...
            if u in self.adj: 
                # for each adjacent node...
                for v in self.adj[u]: 
                    # search for all nodes reachable from *it*...
                    for w in self.search(v, visited): 
                        # and yield each one.
                        yield w

# %%
d = DiGraph([(1,2),(1,3),(2,4),(4,3),(4,1)])

# %%
print(d)
# Out:
# 1 -> 2
# 1 -> 3
# 2 -> 4
# 4 -> 3
# 4 -> 1

# %%
[v for v in d.search(1)]
# Out:
# [1, 2, 4, 3]

# %%
[v for v in d.search(4)]
# Out:
# [4, 3, 1, 2]

# %%
[v for v in d.search(2)]
# Out:
# [2, 4, 3, 1]

# %%
[v for v in d.search(3)]
# Out:
# [3]

# %%
 [v for v in d.search(1)]
# Out:
# [1, 2, 4, 3]
